# %% [markdown]
# <a href="https://colab.research.google.com/github/paolaportilloj/Visualizaci-n-de-datos-para-la-toma-de-decisiones/blob/main/Dia_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path="https://raw.githubusercontent.com/tec03/Datasets/main/datasets/Cartwheeldata.csv"

# %%
import pandas as pd

# %%
df=pd.read_csv(path)
df.tail()
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
cols=df.columns

# %%
df.shape
# Out:
# (25, 12)

# %%
type(cols)
# Out:
# pandas.core.indexes.base.Index

# %%
cols
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
cols=cols.to_list()
type(cols)
# Out:
# list

# %%
cols.sort()

# %%
cols
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df.Height
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
type(df.Height)
# Out:
# pandas.core.series.Series

# %%
df["Height"]
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
type(df["Height"])
# Out:
# pandas.core.series.Series

# %%
x=df[["Height"]]

# %%
x
# Out:
#     Height
# 0    62.00
# 1    62.00
# 2    66.00
# 3    64.00
# 4    73.00
# 5    75.00
# 6    75.00
# 7    65.00
# 8    74.00
# 9    63.00
# 10   69.50
# 11   62.75
# 12   65.00
# 13   61.50
# 14   73.00
# 15   71.00
# 16   61.50
# 17   66.00
# 18   70.00
# 19   68.00
# 20   69.00
# 21   71.00
# 22   70.00
# 23   69.00
# 24   65.00

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Age","Height"]].head(2)
# Out:
#    Age  Height
# 0   56    62.0
# 1   26    62.0

# %%
cols
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
df[["Age","CWDistance","Complete"]]
# Out:
#     Age  CWDistance Complete
# 0    56          79        Y
# 1    26          70        Y
# 2    33          85        Y
# 3    39          87        Y
# 4    27          72        N
# 5    24          81        N
# 6    28         107        Y
# 7    22          98        Y
# 8    29         106        N
# 9    33          65        Y
# 10   30          96        Y
# 11   28          79        Y
# 12   25          92        Y
# 13   23          66        Y
# 14   31          72        Y
# 15   26         115        Y
# 16   26          90        N
# 17   27          74        Y
# 18   23          64        Y
# 19   24          85        Y
# 20   23          66        N
# 21   29         101        Y
# 22   25          82        Y
# 23   26          63        Y
# 24   23          67        N

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.columns[1:5]
# Out:
# Index(['Age', 'Gender', 'GenderGroup', 'Glasses'], dtype='object')

# %%
favs= ["Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
       'Height', 'Wingspan', 'CWDistance']
# Out:
#   File "<ipython-input-29-ef55e2621dd2>", line 1
#     favs= ["Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#                                                                      ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# loc y iloc
#
# loc=> df.loc

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      0
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
df

# %%
df.loc[5:10,'Age':'CWDistance']
# Out:
#     Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 5    24      M            2       N             0    75.0      71.0
# 6    28      M            2       N             0    75.0      76.0
# 7    22      F            1       N             0    65.0      62.0
# 8    29      M            2       Y             1    74.0      73.0
# 9    33      F            1       Y             1    63.0      60.0
# 10   30      M            2       Y             1    69.5      66.0
#
#     CWDistance
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96

# %%
df.iloc[5:11,1:9]
# Out:
#     Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 5    24      M            2       N             0    75.0      71.0
# 6    28      M            2       N             0    75.0      76.0
# 7    22      F            1       N             0    65.0      62.0
# 8    29      M            2       Y             1    74.0      73.0
# 9    33      F            1       Y             1    63.0      60.0
# 10   30      M            2       Y             1    69.5      66.0
#
#     CWDistance
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96

# %%
df.loc[5:11,['Age','CWDistance']]
# Out:
#     Age  CWDistance
# 5    24          81
# 6    28         107
# 7    22          98
# 8    29         106
# 9    33          65
# 10   30          96
# 11   28          79

# %%
df.iloc[5:11,1:9]
# Out:
#     Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 5    24      M            2       N             0    75.0      71.0
# 6    28      M            2       N             0    75.0      76.0
# 7    22      F            1       N             0    65.0      62.0
# 8    29      M            2       Y             1    74.0      73.0
# 9    33      F            1       Y             1    63.0      60.0
# 10   30      M            2       Y             1    69.5      66.0
#
#     CWDistance
# 5           81
# 6          107
# 7           98
# 8          106
# 9           65
# 10          96

# %%
df.iloc[5:11,-3:]
# Out:
#    Complete  CompleteGroup  Score
# 5         N              0      3
# 6         Y              1     10
# 7         Y              1      9
# 8         N              0      5
# 9         Y              1      8
# 10        Y              1      6

# %%
df.iloc[5:11, :3]
# Out:
#     ID  Age Gender
# 5    6   24      M
# 6    7   28      M
# 7    8   22      F
# 8    9   29      M
# 9   10   33      F
# 10  11   30      M

# %%
df.iloc[5:11,:]
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 5    6   24      M            2       N             0    75.0      71.0
# 6    7   28      M            2       N             0    75.0      76.0
# 7    8   22      F            1       N             0    65.0      62.0
# 8    9   29      M            2       Y             1    74.0      73.0
# 9   10   33      F            1       Y             1    63.0      60.0
# 10  11   30      M            2       Y             1    69.5      66.0
#
#     CWDistance Complete  CompleteGroup  Score
# 5           81        N              0      3
# 6          107        Y              1     10
# 7           98        Y              1      9
# 8          106        N              0      5
# 9           65        Y              1      8
# 10          96        Y              1      6

# %%
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
df.Glasses.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df.Height.unique()
# Out:
# array([62.  , 66.  , 64.  , 73.  , 75.  , 65.  , 74.  , 63.  , 69.5 ,
#        62.75, 61.5 , 71.  , 70.  , 68.  , 69.  ])

# %%
df.groupby(['Gender','Glasses']).size()
# Out:
# Gender  Glasses
# F       N          4
#         Y          8
# M       N          7
#         Y          6
# dtype: int64

# %%
df.groupby(['Gender']).size()
# Out:
# Gender
# F    12
# M    13
# dtype: int64

# %%
df[['Gender','Glasses']].value_counts()
# Out:
# Gender  Glasses
# F       Y          8
# M       N          7
#         Y          6
# F       N          4
# dtype: int64
