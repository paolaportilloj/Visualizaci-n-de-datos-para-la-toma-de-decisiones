# %% [markdown]
# <a href="https://colab.research.google.com/github/paolaportilloj/Visualizaci-n-de-datos-para-la-toma-de-decisiones/blob/main/dia4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
path='https://raw.githubusercontent.com/tec03/Datasets/main/datasets/multi_index.csv'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(path,
                 header = [0,1],
                 index_col = [0,1]
                 )
df
# Out:
#                                 Night                             \
#                               Weather       Wind Max Temperature
# City      Date
# London    01/07/19             Shower  SW 16 mph              18
#           02/07/19         Heavy rain  SW 16 mph              17
#           03/07/19         Heavy rain  SW 16 mph              19
#           04/07/19      Mostly cloudy  SW 16 mph              23
# Oxford    01/07/19             Shower  SW 16 mph              19
#           02/07/19             Shower  SW 16 mph              19
#           03/07/19  Scattered showers  SW 16 mph              22
#           04/07/19             Shower  SW 16 mph              21
# Cambridge 01/07/19             Shower  SW 16 mph              17
#           02/07/19  Scattered showers   E 20 mph              16
#           03/07/19  Scattered showers  SE 10 mph              16
#           04/07/19      Mostly cloudy   S 25 mph              16
#
#                                   Day
# ...

# %%
df.index
# Out:
# MultiIndex([(   'London', '01/07/19'),
#             (   'London', '02/07/19'),
#             (   'London', '03/07/19'),
#             (   'London', '04/07/19'),
#             (   'Oxford', '01/07/19'),
#             (   'Oxford', '02/07/19'),
#             (   'Oxford', '03/07/19'),
#             (   'Oxford', '04/07/19'),
#             ('Cambridge', '01/07/19'),
#             ('Cambridge', '02/07/19'),
#             ('Cambridge', '03/07/19'),
#             ('Cambridge', '04/07/19')],
#            names=['City', 'Date'])

# %%
df.columns.levels
# Out:
# FrozenList([['Day', 'Night'], ['Max Temperature', 'Weather', 'Wind']])

# %%
df.loc[['London', 'Oxford'],
       'Day']
# Out:
#                            Weather       Wind  Max Temperature
# City   Date
# London 01/07/19             Shower  SW 16 mph               28
#        02/07/19             Shower  SW 16 mph               29
#        03/07/19  Scattered showers  SW 16 mph               29
#        04/07/19      Mostly cloudy  SW 16 mph               31
# Oxford 01/07/19             Shower  SW 13 mph               25
#        02/07/19             Shower  SW 16 mph               26
#        03/07/19  Scattered showers  SW 16 mph               28
#        04/07/19             Shower  SW 14 mph               25

# %%
df.loc['Cambridge','Night']
# Out:
#                     Weather       Wind  Max Temperature
# Date
# 01/07/19             Shower  SW 16 mph               17
# 02/07/19  Scattered showers   E 20 mph               16
# 03/07/19  Scattered showers  SE 10 mph               16
# 04/07/19      Mostly cloudy   S 25 mph               16

# %%
df.loc['Cambridge','Night'].loc[:, 'Weather'].to_frame()
# Out:
#                     Weather
# Date
# 01/07/19             Shower
# 02/07/19  Scattered showers
# 03/07/19  Scattered showers
# 04/07/19      Mostly cloudy

# %%
df.columns
# Out:
# MultiIndex([('Night',         'Weather'),
#             ('Night',            'Wind'),
#             ('Night', 'Max Temperature'),
#             (  'Day',         'Weather'),
#             (  'Day',            'Wind'),
#             (  'Day', 'Max Temperature')],
#            )

# %%
df.loc['Cambridge',
       ('Night',         'Weather')].to_frame()
# Out:
#                       Night
#                     Weather
# Date
# 01/07/19             Shower
# 02/07/19  Scattered showers
# 03/07/19  Scattered showers
# 04/07/19      Mostly cloudy

# %%
df.loc['Cambridge',:]
# Out:
#                       Night                                           Day  \
#                     Weather       Wind Max Temperature            Weather
# Date
# 01/07/19             Shower  SW 16 mph              17             Shower
# 02/07/19  Scattered showers   E 20 mph              16  Scattered showers
# 03/07/19  Scattered showers  SE 10 mph              16  Scattered showers
# 04/07/19      Mostly cloudy   S 25 mph              16             Shower
#
#
#                Wind Max Temperature
# Date
# 01/07/19  SW 16 mph              24
# 02/07/19   E 20 mph              21
# 03/07/19  SE 10 mph              22
# 04/07/19   S 25 mph              22

# %%
df.loc['Cambridge', (slice(None), 'Wind')]
# Out:
#               Night        Day
#                Wind       Wind
# Date
# 01/07/19  SW 16 mph  SW 16 mph
# 02/07/19   E 20 mph   E 20 mph
# 03/07/19  SE 10 mph  SE 10 mph
# 04/07/19   S 25 mph   S 25 mph

# %%
df.columns.levels
# Out:
# FrozenList([['Day', 'Night'], ['Max Temperature', 'Weather', 'Wind']])

# %%
df.index
# Out:
# MultiIndex([(   'London', '01/07/19'),
#             (   'London', '02/07/19'),
#             (   'London', '03/07/19'),
#             (   'London', '04/07/19'),
#             (   'Oxford', '01/07/19'),
#             (   'Oxford', '02/07/19'),
#             (   'Oxford', '03/07/19'),
#             (   'Oxford', '04/07/19'),
#             ('Cambridge', '01/07/19'),
#             ('Cambridge', '02/07/19'),
#             ('Cambridge', '03/07/19'),
#             ('Cambridge', '04/07/19')],
#            names=['City', 'Date'])

# %%
df.loc[(   'London', '02/07/19'),:]
# Out:
# Night  Weather            Heavy rain
#        Wind                SW 16 mph
#        Max Temperature            17
# Day    Weather                Shower
#        Wind                SW 16 mph
#        Max Temperature            29
# Name: (London, 02/07/19), dtype: object

# %%
df.loc[(   'London', '02/07/19'),:].to_frame()
# Out:
#                            London
#                          02/07/19
# Night Weather          Heavy rain
#       Wind              SW 16 mph
#       Max Temperature          17
# Day   Weather              Shower
#       Wind              SW 16 mph
#       Max Temperature          29

# %%
df.loc[(   'London', '02/07/19'),:].to_frame().transpose()
# Out:
#                       Night                                Day             \
#                     Weather       Wind Max Temperature Weather       Wind
# London 02/07/19  Heavy rain  SW 16 mph              17  Shower  SW 16 mph
#
#
#                 Max Temperature
# London 02/07/19              29

# %%
df.loc[( slice(None), '02/07/19'),('Night','Weather')]
# Out:
# City       Date
# London     02/07/19           Heavy rain
# Oxford     02/07/19               Shower
# Cambridge  02/07/19    Scattered showers
# Name: (Night, Weather), dtype: object

# %%
df.loc[( slice(None), ['02/07/19','04/07/19']),('Night', 'Weather')].to_frame()
# Out:
#                                 Night
#                               Weather
# City      Date
# London    02/07/19         Heavy rain
# Oxford    02/07/19             Shower
# Cambridge 02/07/19  Scattered showers
# London    04/07/19      Mostly cloudy
# Oxford    04/07/19             Shower
# Cambridge 04/07/19      Mostly cloudy
